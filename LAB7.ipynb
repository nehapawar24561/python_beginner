# %% [markdown]
# # LAB 7 : Redesigning LAB3

# %% [markdown]
# <b> Goal: </b> Redesign LAB session 3.
#
# # Base Visualization Claim :
#  Financial Markets do punish security breaches.

# %% [markdown]
# <b> Visualization to be redesigned: </b>

# %%
from IPython.display import Image
Image("/Users/MyMac/Desktop/LAB 7/LAB3_tableau.png")

# %% [markdown]
# # Problems with this visualization:
#
# 1. One can not comprehend the relationship between databreaches and stock prices looking at this graph.
# 2. No explanations are given for choosing Staples and Nintendo to prove the claim; proving claim for 2 companies does not mean that whole industry is reacting in the same manner.
# 3. Worksheet name is not changed.
# 4. Data sources are not mentioned as reference.
# 5. Stock price measure is taken as Average of stock prices for a year, which is not the correct way to understand if financial markets are punishing data breaches.
# 6. Stock price data is not connected to data breach data; Visualization should show some information about databreach like number of records lost, sensitivity of data etc.

# %% [markdown]
# # Redesigned Visualization Claim:
#
# Financial Markets do NOT punish Security breaches.

# %% [markdown]
# Tableau Public Link for intermediate visualization: https://public.tableau.com/profile/neha4079#!/vizhome/FinancialMarketsdoNOTpunishSecurityBreaches/Sheet3?publish=yes

# %%
Image("/Users/MyMac/Desktop/LAB 7/LAB7.png")

# %% [markdown]
# This is the intermediate version of the visualization, I have mentioned roadmap below to improve it further.
#
# Above visualization shows stock price variation over the years for 5 entities from different industries. But it does not show connection between stock prices and its connection with data breaches.
#
# <b> Perception </b> for this visualization is stock prices.
#
# <b> Comprehension </b> for this visualization is relationship between stock prices and databreach information(number of records lost, data sensitivity etc)

# %% [markdown]
# # Roadmap:
#
# To redesign this visualization, I would take steps mentioned below:
#
# 1. While analyzing data to figure out entites for redesigning the visualization, I created couple of intermediate visualizations.
# 2. For some entities, the average stock price per year is moving down during the data breach timeframe and for some entities it is moving up or moving steadily.
# 3. After researching more about databreaches related to those entities, I realized that though the short term and long term effect varies by industry,Financial markets do NOT punish security data breaches
# 4. Next I would figure out couple of entities for each industry type such as financial, tech, healthcare etc.
# 5. Rather than taking average stock price per year, I would limit the years in the dataset, so that I can correctly identify the stock price effect during data breach timeframe.
# 6. Also, to depict data breach effect correctly, I will map number of records lost or data sensitivity along with stock prices and timeline.
# 7. The final version of the visualization should show stock prices going steady during the databreach timeframe; Short time and long time behaviour is expected to differ for different types of industries.

# %% [markdown]
# <b> Why did I choose Vodafone, Yahoo, NASDAQ, UPS, Home Depot to prove my claim? </b>
#
# I decided to take entities from different industry types to prove my claim. After doing hit and trial for a number of industries, I chose Vodafone from telecom industry, Yahoo from web, NASDAQ from financial, UPS and Home Depot from retail industry.
#
# 1. Vodafone had cyber attack in 2013 and they lost 2000000 records with customer credit card information.
# 2. Yahoo's SSN/Personal details data was compromised and they lost 1000000000 and 500000000 records in 2013 and 2014 respectively.
# 3. Financial Institution NASDAQ lost 500000 email address/Online information in 2014.
# 4. UPS and Home Depot lost 4000000 and 56000000 credit card records respectively in 2014 data breach.
#
# Looking at the intermediate visualization, from high level we can see that the stock prices for entities mentioned above did not move down during the data breach year.
