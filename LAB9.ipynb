# %% [markdown]
# # Visualization to be redesigned

# %%
from IPython.display import Image
Image("/Users/MyMac/Desktop/LAB9/LAB6.png")

# %% [markdown]
# # Problems with this visualization:
#
# 1. Metrics are not integrated
# 2. no datasources mentioned
# 3. It does not give actual information for recruiters
# 4. One can not compare and contrast looking at this dashboard
# 5. It does not have any claim/argument
# 6. It does not satisfy the objective of the given assignment

# %% [markdown]
# # Roadmap:

# %% [markdown]
# <b> Claim: </b> SCU MSIS students are perfect candidates for hiring!
#
# <b> Target Audience: </b> Recruiters looking for University Graduate Students.
#
# <b> Metric: </b> Ideally the metric to compare university programs for hiring their candiates is a combination of Required skillset for prospective Job Profile, University Rankings, Univeristy alumni work statistics.

# %% [markdown]
# # Improved visualization:

# %%
Image("/Users/MyMac/Desktop/LAB9/LAB9_final.png")

# %% [markdown]
# PFB link for Tableau public visualization:
#
# https://public.tableau.com/profile/neha4079#!/vizhome/LAB9/Dashboard1?publish=yes

# %% [markdown]
# <b> Conclusion: </b> University ranking along with Course Curriculum show that students are well-versed with required skillset for prospective job opportunities.
#
# Also, as SCU is on quarter system, with the extensive course curriculum it proves that students can work in dynamic and fast paced environment.

# %% [markdown]
# <b> Roadmap for Improvement: </b> I have not integrated metrics to give clear picture with comparison with other universities data about their students' skillset and rankings.
