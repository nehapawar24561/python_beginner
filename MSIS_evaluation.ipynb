# %% [markdown]
# Student Name: Neha Pawar
# Student ID: W1286279

# %% [markdown]
# <b> CLAIM: MSIS program at Santa Clara University is one amongst best MSIS progams offered in California.</b>

# %% [markdown]
# One of the major reasons that Santa Clara University MSIS program is preferred over other university's MSIS program is that the university is in the heart of Silicon Valley. Below screenshot shows employement of Computer and Information System engineers, by State, by May 2016.
# Reference: https://www.bls.gov/oes/current/oes113021.htm

# %% [markdown]
# I have used KPIs such as University comparison in west coast, Roles and average salary after MSIS completion and University rankings.

# %% [markdown]
# <b> University Comparison in West Coast </b>

# %% [markdown]
# Imported data from http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html to compare Santa Clara University, San Jose University and University of San Fransico with respect to Information Systems Program.

# %%
from bs4 import BeautifulSoup
import urllib2
import requests
from IPython.display import Image

# %%
data_compare = requests.get('http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html')
data_compare
# Out:
# <Response [200]>

# %%
html_compare = BeautifulSoup(data_compare.content, 'html.parser')

# %%
#print(html_data.prettify())

# %%
table = html_compare.find('table')

# %%
table_compare = table.find('tbody')
#print(table_compare)

# %%
for row in table_compare.find_all('tr'):
    for cell in row.find_all('td'):
        print(cell)
# Out:
# <td> <b>Rankings (2013)</b> </td>
# <td> Ranked 2nd among universities in the Western region* </td>
# <td> Named the 9th best public school in the Western region* </td>
# <td> 106th among national universities in the U.S.*</td>
# <td> <b>Location</b> </td>
# <td> Santa Clara, CA (about 2 miles from San Jose) </td>
# <td> San Jose, CA </td>
# <td> San Francisco, CA (roughly 42 miles from San Jose</td>
# <td> <b>School Type</b> </td>
# <td> 4-year, private not-for-profit </td>
# <td> 4-year, public </td>
# <td> 4-year, private not-for-profit</td>
# <td> <b>Tuition &amp; Fees (2012-2013)</b> </td>
# <td> $23,976 (graduate)** </td>
# <td> $6,852, in-state; $18,510, out-of-state (undergrad)** </td>
# <td> $965 per credit (bachelor's completion program)***; $20,390 per year (graduate)**</td>
# <td> <b>Information Technology Degrees and Programs Offered</b> </td>
# <td> Master's degree </td>
# <td> Bachelor's degree </td>
# <td> Adult bachelor's completion and master's degrees</td>
# <td> <b>Information Technology Degrees Awarded (All Levels) in 2011-2012</b> </td>
# <td> 22** </td>
# <td> 1,242 for business administration and management (information technology not provided)** </td>
# <td> 248 for business administration and management (information technology not provided)**</td>
# <td> <b>Most Popular Information Technology Programs in 2011-2012</b> </td>
# <td> Master of Science in Information Systems (22 degrees awarded)** </td>
# <td> N/A </td>
# <td> N/A</td>
# <td> <b>Undergrad Graduation Rate (in 150% of normal program time) for 2005 Entering Class</b> </td>
# <td> N/A </td>
# <td> 46%** </td>
# <td> 70%**</td>
# <td> <b>Noteworthy</b> </td>
# <td> 12th among schools in the Western region for the best educational value in 2013* </td>
# <td> Listed 38th among universities in the Western region in 2013* </td>
# <td> Ranked 100th nationally by high school counselors in 2012*</td>

# %%
data_compare = {
    'Category' : [],
    'Santa Clara University' : [],
    'San Jose State University' : [],
    'University of San Francisco' : []
}

table_names = ['Category','Santa Clara University','San Jose State University','University of San Francisco']
count = 0
for row in table_compare.find_all('tr'):
    for cell in row.find_all('td'):
        #print( table_names[count%4] +":"+ cell.get_text())
        data_compare[table_names[count%4]].append( cell.get_text() )
        count= count+1
    
import pandas as pd
datacompare = pd.DataFrame(data_compare)

# %%
datacompare.head(2)
# Out:
#             Category                          San Jose State University  \
# 0   Rankings (2013)    Named the 9th best public school in the Weste...
# 1          Location                                       San Jose, CA
#
#                               Santa Clara University  \
# 0   Ranked 2nd among universities in the Western ...
# 1     Santa Clara, CA (about 2 miles from San Jose)
#
#                          University of San Francisco
# 0     106th among national universities in the U.S.*
# 1   San Francisco, CA (roughly 42 miles from San ...

# %%
datacompare.to_csv('Dataset1.csv', index=False, encoding='utf-8')

# %% [markdown]
# The image below shows the comparison between San Jose State University, Santa Clara University and University of San Fransico. Santa Clara University IS program is ranked second amongst the western universities.
# PS: This is not the latest data.

# %%
Image("Screenshots/University_comparison.png")

# %% [markdown]
# <b> Roles and respective average salary data</b>

# %% [markdown]
# Coverted table from https://www.payscale.com/research/US/Degree=Master_of_Information_Science_(MIS)/Salary to dataframe.

# %%
salary_data = pd.read_html('Paysalary.html')
salary_data
# Out:
# [                                                    0         1            2
#  0                                                 Job   Average     Min  Max
#  1                                                 NaN       NaN          NaN
#  2                     Software Engineer  111 profiles   $86,916  $65K  $122K
#  3                                                 NaN       NaN          NaN
#  4                           Data Analyst  83 profiles   $63,839   $46K  $82K
#  5                                                 NaN       NaN          NaN
#  6                   Business Analyst, IT  69 profiles   $67,970     $51K$86K
#  7                                                 NaN       NaN          NaN
#  8                                                 NaN       NaN          NaN
#  9                                                 NaN       NaN          NaN
#  10     Information Technology (IT) Manager67 profiles  $100,541    $65K$131K
#  11                                                NaN       NaN          NaN
#  12  Project Manager, Information Technology (IT)54...   $90,546    $64K$119K
#  13                                                NaN       NaN          NaN
#  14                      Software Developer47 profiles   $72,474    $58K$104K
#  15                                                NaN       NaN          NaN
#  16    Information Technology (IT) Director46 profiles  $118,960    $73K$171K
#  17                                                NaN       NaN          NaN
#  18                                                NaN       NaN          NaN
#  19                                                NaN       NaN          NaN]

# %%
salary_data = salary_data[0]
salary_data.columns = ['MSIS Job positions', 'Average Salary', 'Min  Max']

# %%
salary_data.head()
# Out:
#                 MSIS Job positions Average Salary     Min  Max
# 0                              Job        Average     Min  Max
# 1                              NaN            NaN          NaN
# 2  Software Engineer  111 profiles        $86,916  $65K  $122K
# 3                              NaN            NaN          NaN
# 4        Data Analyst  83 profiles        $63,839   $46K  $82K

# %%
#Removing rows with null values
salary_data = salary_data.dropna(axis=0,how='any')

# %%
salary_data.drop(salary_data.index[:1], inplace=True)

# %%
salary_data.to_csv('salarydata.csv', index=False, encoding='utf-8')

# %% [markdown]
# Salary_data graph shows Salary comparison amongst the MSIS job positions

# %%
Image("Screenshots/Salary_Data.png")

# %% [markdown]
# <b> University Ranking </b>

# %% [markdown]
# Converted data from http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/ to dataframe:

# %%
url = 'http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/'

# %%
data = pd.read_html(url, header = 0)

# %%
data1 = data[0]
data1.head()
# Out:
#    Sr. No                                         University      Program
# 0       1                 Carnegie Mellon University (Heinz)         MISM
# 1       2          Indiana University – Bloomington (Kelley)        MS IS
# 2       3       University of California, Berkeley (iSchool)         MIMS
# 3       4  University of Washington, Seattle (iSchool/Fos...  MS IM/MS IS
# 4       5                      University of Arizona (Eller)       MS MIS

# %%
data1.columns = ['RANKING', 'UNIVERSITY', 'PROGRAM']

# %%
data1.dtypes
# Out:
# RANKING        int64
# UNIVERSITY    object
# PROGRAM       object
# dtype: object

# %%
data1.head()
# Out:
#    RANKING                                         UNIVERSITY      PROGRAM
# 0        1                 Carnegie Mellon University (Heinz)         MISM
# 1        2          Indiana University – Bloomington (Kelley)        MS IS
# 2        3       University of California, Berkeley (iSchool)         MIMS
# 3        4  University of Washington, Seattle (iSchool/Fos...  MS IM/MS IS
# 4        5                      University of Arizona (Eller)       MS MIS

# %%
df = pd.DataFrame(data1)
df.head()
# Out:
#    RANKING                                         UNIVERSITY      PROGRAM
# 0        1                 Carnegie Mellon University (Heinz)         MISM
# 1        2          Indiana University – Bloomington (Kelley)        MS IS
# 2        3       University of California, Berkeley (iSchool)         MIMS
# 3        4  University of Washington, Seattle (iSchool/Fos...  MS IM/MS IS
# 4        5                      University of Arizona (Eller)       MS MIS

# %%
df.to_csv('univ_ranking.csv', index=False, encoding='utf-8')

# %%
#Changed university rankings graph
Image("Screenshots/Univ_ranking.png")

# %% [markdown]
# <b> Student Teacher Ratio</b>

# %% [markdown]
# Converted table from https://www.universities.com/find/california/best/management-information-systems-degrees to dataframe.

# %%
url2 = 'file:///Users/MyMac/Desktop/student_teacher.html'
student_teacher = pd.read_html(url2, header = 0)

# %%
student_teacher = student_teacher[0]
student_teacher.head()
# Out:
#   School Logo                                        School Name  \
# 0         NaN            Santa Clara University  Santa Clara, CA
# 1         NaN     University of San Francisco  San Francisco, CA
# 2         NaN       Loyola Marymount University  Los Angeles, CA
# 3         NaN  California Lutheran University  Thousand Oaks, CA
# 4         NaN               University of Redlands  Redlands, CA
#
#   Average tuition Student Teacher Ratio  Enrolled Students
# 0             5/5                14 : 1               8680
# 1             5/5                15 : 1              10797
# 2             5/5                13 : 1               9392
# 3             5/5                16 : 1               4126
# 4             5/5                16 : 1               5215

# %%
stud_teach = pd.DataFrame(student_teacher)
stud_teach.head()
# Out:
#   School Logo                                        School Name  \
# 0         NaN            Santa Clara University  Santa Clara, CA
# 1         NaN     University of San Francisco  San Francisco, CA
# 2         NaN       Loyola Marymount University  Los Angeles, CA
# 3         NaN  California Lutheran University  Thousand Oaks, CA
# 4         NaN               University of Redlands  Redlands, CA
#
#   Average tuition Student Teacher Ratio  Enrolled Students
# 0             5/5                14 : 1               8680
# 1             5/5                15 : 1              10797
# 2             5/5                13 : 1               9392
# 3             5/5                16 : 1               4126
# 4             5/5                16 : 1               5215

# %%
stud_teach.to_csv('stud_teach.csv', index=False, encoding='utf-8')

# %% [markdown]
# This graph shows different university's student-teacher ratio. SCU has the second best student-teacher ratio.

# %%
Image("stud_teach.png")

# %% [markdown]
# To support the three KPIs discussed above, the SCU website screenshot shows class demographics, academics, professional profile along with alumni work placements.

# %% [markdown]
# Prospective students and recruiters will also refer to Santa Clara University official website for the KPIs such as Average GRE, GMAT, undegraduate GPA, student diversity, alumni workplaces.
# Reference: https://www.scu.edu/business/ms-information-systems/prospective-students/class-profile/

# %%
Image("scu_msis_data.png")
